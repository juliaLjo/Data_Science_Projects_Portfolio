# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Project-description" data-toc-modified-id="Project-description-1">Project description</a></span></li><li><span><a href="#Data-Preparation" data-toc-modified-id="Data-Preparation-2">Data Preparation</a></span></li><li><span><a href="#Data-Analysis" data-toc-modified-id="Data-Analysis-3">Data Analysis</a></span><ul class="toc-item"><li><span><a href="#Trend-and-Seasonality" data-toc-modified-id="Trend-and-Seasonality-3.1">Trend and Seasonality</a></span></li><li><span><a href="#Feature-Generation" data-toc-modified-id="Feature-Generation-3.2">Feature Generation</a></span></li><li><span><a href="#Train-&amp;-Test-Split" data-toc-modified-id="Train-&amp;-Test-Split-3.3">Train &amp; Test Split</a></span></li></ul></li><li><span><a href="#Model-Selection" data-toc-modified-id="Model-Selection-4">Model Selection</a></span><ul class="toc-item"><li><span><a href="#Linear-Regression" data-toc-modified-id="Linear-Regression-4.1">Linear Regression</a></span></li><li><span><a href="#Random-Forest-Regression" data-toc-modified-id="Random-Forest-Regression-4.2">Random Forest Regression</a></span></li><li><span><a href="#KNeighborsRegressor" data-toc-modified-id="KNeighborsRegressor-4.3">KNeighborsRegressor</a></span></li><li><span><a href="#LGBMRegressor" data-toc-modified-id="LGBMRegressor-4.4">LGBMRegressor</a></span></li><li><span><a href="#CatBoost" data-toc-modified-id="CatBoost-4.5">CatBoost</a></span></li><li><span><a href="#Dummy-models" data-toc-modified-id="Dummy-models-4.6">Dummy models</a></span><ul class="toc-item"><li><span><a href="#Constant-Model" data-toc-modified-id="Constant-Model-4.6.1">Constant Model</a></span></li><li><span><a href="#Naive-Model" data-toc-modified-id="Naive-Model-4.6.2">Naive Model</a></span></li></ul></li></ul></li><li><span><a href="#Models-Comparison" data-toc-modified-id="Models-Comparison-5">Models Comparison</a></span></li><li><span><a href="#Conclusion" data-toc-modified-id="Conclusion-6">Conclusion</a></span></li></ul></div>

# %% [markdown]
# # Project description

# %% [markdown]
# Sweet Lift Taxi company has collected historical data on taxi orders at airports. To attract more drivers during peak hours, the amount of taxi orders for the next hour needs to be predicted.<br>
# <b>The task</b> is to develop a model for taxi orders predictions with RMSE no more than 48. The data needs to be re-sampled by one hour.<br>
# <b>Data description</b>
# Time series data was provided and it includes:<br>
# <i>datetime</i> — a time stamp<br>
# <i>num_orders</i> — number of order per a time stamp<br>

# %% [markdown]
# # Data Preparation

# %%
import pandas as pd
import numpy as np
from math import sqrt
from sklearn.model_selection import train_test_split, TimeSeriesSplit
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_squared_error, mean_absolute_error
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from catboost import CatBoostRegressor
from lightgbm import LGBMRegressor
from IPython.display import Image
import sys
import warnings
if not sys.warnoptions:
       warnings.simplefilter("ignore")

# %%
df = pd.read_csv('taxi.csv', index_col=['datetime'], parse_dates=['datetime'])
df.sort_index(inplace=True)

# %%
print('Begining of the period', df.index.min(), 'End of the period', df.index.max())
# Out:
# Begining of the period 2018-03-01 00:00:00 End of the period 2018-08-31 23:50:00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 26496 entries, 2018-03-01 00:00:00 to 2018-08-31 23:50:00
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   num_orders  26496 non-null  int64
# dtypes: int64(1)
# memory usage: 414.0 KB

# %% [markdown]
# The data set contains 26496 rows and there are no missing values. We set time stamp data as indices and sorted the data by the time stamp in chronological order. The observed data is for the period of time from March 1st to August 31st.

# %% [markdown]
# # Data Analysis

# %%
df.plot();

# %% [markdown]
# The project's requirement is to re-sample data by one hour.

# %%
df = df.resample('1H').sum()

# %%
df.plot();

# %% [markdown]
# The graph looks still pretty dense after re-sampling by one hour. For the better understanding of what features we need, we might look at different levels of re-sampling later.

# %% [markdown]
# ## Trend and Seasonality

# %%
decomposed = seasonal_decompose(df)

# %%
plt.figure(figsize=(8, 8))

plt.subplot(311)
decomposed.trend.plot(ax=plt.gca())
plt.title('Trend')
plt.subplot(312)
decomposed.seasonal.plot(ax=plt.gca())
plt.title('Seasonality')
plt.subplot(313)
decomposed.resid.plot(ax=plt.gca())
plt.title('Residuals')

plt.tight_layout()

# %% [markdown]
# Let's take at look at amplitude of swings of the seasonality up close. To reduce the frequency of lines we might need to create a copy of the data set and re-sample it by one day.

# %%
df_day = df.resample('1D').sum()
decomposed = seasonal_decompose(df_day)

# %%
Y = decomposed.seasonal['2018-05-01':'2018-05-31']
x = decomposed.seasonal['2018-05-01':'2018-05-31'].index
weekday_map= {0:'MON', 1:'TUE', 2:'WED', 3:'THU', 4:'FRI', 5:'SAT', 6:'SUN'}
dow = decomposed.seasonal['2018-05-01':'2018-05-31'].index.dayofweek.map(weekday_map)

fig = plt.figure(figsize=(20, 10))
ax1 = fig.add_subplot(111)
ax2 = ax1.twiny()
ax2.set_xticks(np.arange(len(x)), minor=False)
ax2.set_xticklabels(dow)
ax1.set_xlim(min(x), max(x))
ax1.plot(x, Y);

# %% [markdown]
# There is obvious seasonality trend in the data: the peak of taxi rides is on Mondays, the second highest peak is on Fridays. That is why we will need to create a day of the week feature.

# %% [markdown]
# ## Feature Generation

# %%
def make_features(data, max_lag, rolling_mean_size):
    data['month'] = data.index.month
    data['day'] = data.index.day
    data['dayofweek'] = data.index.dayofweek
    data['hour'] = data.index.hour
    
    for lag in range(1, max_lag + 1):
        data['lag_{}'.format(lag)] = data['num_orders'].shift(lag)

    data['rolling_mean'] = data['rolling_mean'] = data['num_orders'].shift().rolling(rolling_mean_size).mean()
    return data

# %%
df = make_features(df, 5, 7)

# %%
df.head(10)
# Out:
#                      num_orders  month  day  dayofweek  hour  lag_1  lag_2  \
# datetime
# 2018-03-01 00:00:00         124      3    1          3     0    NaN    NaN
# 2018-03-01 01:00:00          85      3    1          3     1  124.0    NaN
# 2018-03-01 02:00:00          71      3    1          3     2   85.0  124.0
# 2018-03-01 03:00:00          66      3    1          3     3   71.0   85.0
# 2018-03-01 04:00:00          43      3    1          3     4   66.0   71.0
# 2018-03-01 05:00:00           6      3    1          3     5   43.0   66.0
# 2018-03-01 06:00:00          12      3    1          3     6    6.0   43.0
# 2018-03-01 07:00:00          15      3    1          3     7   12.0    6.0
# 2018-03-01 08:00:00          34      3    1          3     8   15.0   12.0
# 2018-03-01 09:00:00          69      3    1          3     9   34.0   15.0
#
#                      lag_3  lag_4  lag_5  rolling_mean
# datetime
# 2018-03-01 00:00:00    NaN    NaN    NaN           NaN
# 2018-03-01 01:00:00    NaN    NaN    NaN           NaN
# 2018-03-01 02:00:00    NaN    NaN    NaN           NaN
# 2018-03-01 03:00:00  124.0    NaN    NaN           NaN
# 2018-03-01 04:00:00   85.0  124.0    NaN           NaN
# 2018-03-01 05:00:00   71.0   85.0  124.0           NaN
# 2018-03-01 06:00:00   66.0   71.0   85.0           NaN
# 2018-03-01 07:00:00   43.0   66.0   71.0     58.142857
# 2018-03-01 08:00:00    6.0   43.0   66.0     42.571429
# 2018-03-01 09:00:00   12.0    6.0   43.0     35.285714

# %% [markdown]
# ## Train & Test Split

# %% [markdown]
# Now that the new features are ready, let's split the data into train and test sets.

# %%
train, test = train_test_split(df, shuffle=False, test_size=0.2)
train = train.dropna()
train_X = train.drop(['num_orders'], axis=1)
test_X = test.drop(['num_orders'], axis=1)
train_y = train['num_orders']
test_y = test['num_orders']

# %% [markdown]
# In order to find best hyper-parameters we will perform grid search cross validation. Since we have time-series data we will use time-aware cross validation technique, which can be explained as follows:

# %%
Image(filename='time_aware_cv.png')

# %% [markdown]
# Source: https://stats.stackexchange.com/questions/14099/using-k-fold-cross-validation-for-time-series-model-selection

# %%
time_split = TimeSeriesSplit(n_splits=3)

# %% [markdown]
# # Model Selection

# %% [markdown]
# ## Linear Regression

# %%
lm = LinearRegression()
lm.fit(train_X, train_y)
# Out:
# LinearRegression()

# %%
# %%time
lm_predictions_test = lm.predict(test_X)
# Out:
# CPU times: user 9.32 ms, sys: 930 µs, total: 10.2 ms
# Wall time: 2.63 ms

# %%
lm_rmse_test = round(mean_squared_error(test_y, lm_predictions_test)**0.5, 2)
print('RMSE on test:', lm_rmse_test)
# Out:
# RMSE on test: 47.52

# %% [markdown]
# ## Random Forest Regression

# %%
rfr = RandomForestRegressor()

# %%
param_grid = { 
    'n_estimators': [10, 25, 50, 75, 100],
    'max_depth' : [i for i in range(3,15,3)]
}

# %%
CV_rfr = GridSearchCV(estimator=rfr, param_grid=param_grid, cv=time_split, scoring='neg_root_mean_squared_error')
CV_rfr.fit(train_X, train_y)
# Out:
# GridSearchCV(cv=TimeSeriesSplit(gap=0, max_train_size=None, n_splits=3, test_size=None),
#              estimator=RandomForestRegressor(),
#              param_grid={'max_depth': [3, 6, 9, 12],
#                          'n_estimators': [10, 25, 50, 75, 100]},
#              scoring='neg_root_mean_squared_error')

# %%
CV_rfr.best_params_
# Out:
# {'max_depth': 12, 'n_estimators': 50}

# %%
-CV_rfr.best_score_
# Out:
# 25.184551050432002

# %%
# %%time
rfr_best_pred_test = CV_rfr.predict(test_X)
# Out:
# CPU times: user 8.25 ms, sys: 1.13 ms, total: 9.38 ms
# Wall time: 8.28 ms

# %%
rfr_rmse_test = round(mean_squared_error(test_y, rfr_best_pred_test)**0.5, 2)
print('RMSE on test:', rfr_rmse_test)
# Out:
# RMSE on test: 45.76

# %% [markdown]
# ## KNeighborsRegressor

# %%
knn = KNeighborsRegressor()

# %%
param_grid = {
        'n_neighbors' : range(1,5,1),
        'algorithm' : ['auto', 'ball_tree', 'kd_tree', 'brute'],
    }
knn_CV = GridSearchCV(estimator = knn, param_grid = param_grid, cv=time_split, scoring = 'neg_root_mean_squared_error')
knn_CV.fit(train_X, train_y)
# Out:
# GridSearchCV(cv=TimeSeriesSplit(gap=0, max_train_size=None, n_splits=3, test_size=None),
#              estimator=KNeighborsRegressor(),
#              param_grid={'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute'],
#                          'n_neighbors': range(1, 5)},
#              scoring='neg_root_mean_squared_error')

# %%
knn_CV.best_params_
# Out:
# {'algorithm': 'auto', 'n_neighbors': 4}

# %%
-knn_CV.best_score_
# Out:
# 33.310054112409034

# %%
# %%time
knn_best_pred_test = knn_CV.predict(test_X)
# Out:
# CPU times: user 42.1 ms, sys: 8.05 ms, total: 50.2 ms
# Wall time: 12.5 ms

# %%
knn_rmse_test = round(mean_squared_error(test_y, knn_best_pred_test)**0.5, 2)
print('RMSE on test:', knn_rmse_test)
# Out:
# RMSE on test: 57.57

# %% [markdown]
# ## LGBMRegressor

# %%
lgbm_model = LGBMRegressor()

# %%
param_grid = {
    'learning_rate': [0.05, 0.1, 0.15],
    'n_estimators': [100, 200, 300, 400], #Number of boosted trees to fit.
    'max_depth': [5, 10, 15, 20, 25] #Maximum tree depth for base learners, <=0 means no limit.
}

# %%
grid_search_lgbm = GridSearchCV(estimator=lgbm_model,
                                param_grid=param_grid,
                                cv=time_split,
                                scoring='neg_root_mean_squared_error')

# %%
grid_search_lgbm.fit(train_X, train_y)
# Out:
# GridSearchCV(cv=TimeSeriesSplit(gap=0, max_train_size=None, n_splits=3, test_size=None),
#              estimator=LGBMRegressor(),
#              param_grid={'learning_rate': [0.05, 0.1, 0.15],
#                          'max_depth': [5, 10, 15, 20, 25],
#                          'n_estimators': [100, 200, 300, 400]},
#              scoring='neg_root_mean_squared_error')

# %%
grid_search_lgbm.best_params_
# Out:
# {'learning_rate': 0.05, 'max_depth': 10, 'n_estimators': 100}

# %%
lgbm_best = LGBMRegressor(learning_rate=0.05, max_depth=10, n_estimators=100)

# %%
lgbm_best.fit(train_X, train_y)
# Out:
# LGBMRegressor(learning_rate=0.05, max_depth=10)

# %%
# %%time
lgbm_predictions_test = lgbm_best.predict(test_X)
# Out:
# CPU times: user 25.2 ms, sys: 4.77 ms, total: 30 ms
# Wall time: 5.16 ms

# %%
lgbm_rmse_test = round(mean_squared_error(test_y, lgbm_predictions_test)**0.5, 2)
print('RMSE on test:', lgbm_rmse_test)
# Out:
# RMSE on test: 45.39

# %% [markdown]
# ## CatBoost

# %%
catboost = CatBoostRegressor()

# %%
param_grid = {'n_estimators': [100, 200],
        'learning_rate': [0.05, 0.1, 0.15],
        'depth': [6, 8, 10],
        'l2_leaf_reg': [1, 3, 5]}

# %%
grid_search_result = catboost.grid_search(param_grid, X=train_X, y=train_y, cv=time_split)
# Out:
# 0:	learn: 73.1823120	test: 99.2036382	best: 99.2036382 (0)	total: 56.5ms	remaining: 5.6s
# 1:	learn: 70.1485756	test: 95.5931749	best: 95.5931749 (1)	total: 62.2ms	remaining: 3.04s
# 2:	learn: 67.2819918	test: 92.6287629	best: 92.6287629 (2)	total: 66.5ms	remaining: 2.15s
# 3:	learn: 64.6433207	test: 89.4009714	best: 89.4009714 (3)	total: 71.8ms	remaining: 1.72s
# 4:	learn: 62.0597538	test: 86.4865719	best: 86.4865719 (4)	total: 76.1ms	remaining: 1.44s
# 5:	learn: 59.5793980	test: 83.6820250	best: 83.6820250 (5)	total: 79.2ms	remaining: 1.24s
# 6:	learn: 57.1685216	test: 80.9777714	best: 80.9777714 (6)	total: 82.7ms	remaining: 1.1s
# 7:	learn: 55.0329115	test: 78.2099326	best: 78.2099326 (7)	total: 86.3ms	remaining: 993ms
# 8:	learn: 52.9825466	test: 75.7136500	best: 75.7136500 (8)	total: 89.6ms	remaining: 906ms
# 9:	learn: 51.0039000	test: 73.2851104	best: 73.2851104 (9)	total: 93.5ms	remaining: 842ms
# 10:	learn: 49.2558679	test: 71.1890139	best: 71.1890139 (10)	total: 97.6ms	remaining: 789ms
# 11:	learn: 47.6097287	test: 69.1840445	best: 69.1840445 (11)	total: 101ms	remaining: 743ms
# 12:	learn: 46.0455767	test: 67.2361137	best: 67.2361137 (12)	total: 106ms	remaining: 709ms
# 13:	learn: 44.4045688	test: 65.0842589	best: 65.0842589 (13)	total: 110ms	remaining: 677ms
# 14:	learn: 42.9885286	test: 63.1475736	best: 63.1475736 (14)	total: 113ms	remaining: 642ms
# 15:	learn: 41.6880979	test: 61.4840647	best: 61.4840647 (15)	total: 119ms	remaining: 627ms
# 16:	learn: 40.4282900	test: 59.7177455	best: 59.7177455 (16)	total: 124ms	remaining: 606ms
# 17:	learn: 39.2392292	test: 58.2590941	best: 58.2590941 (17)	total: 130ms	remaining: 594ms
# 18:	learn: 38.0246942	test: 56.5460284	best: 56.5460284 (18)	total: 135ms	remaining: 574ms
# 19:	learn: 36.9549109	test: 55.1257088	best: 55.1257088 (19)	total: 138ms	remaining: 552ms
# 20:	learn: 36.1275967	test: 54.1056110	best: 54.1056110 (20)	total: 139ms	remaining: 523ms
# 21:	learn: 35.2793122	test: 52.8625107	best: 52.8625107 (21)	total: 142ms	remaining: 502ms
# 22:	learn: 34.4345508	test: 51.6058084	best: 51.6058084 (22)	total: 145ms	remaining: 484ms
# 23:	learn: 33.6020727	test: 50.3865485	best: 50.3865485 (23)	total: 148ms	remaining: 468ms
# 24:	learn: 32.7184811	test: 49.3116136	best: 49.3116136 (24)	total: 151ms	remaining: 452ms
# 25:	learn: 32.0172931	test: 48.3131435	best: 48.3131435 (25)	total: 154ms	remaining: 437ms
# 26:	learn: 31.3614631	test: 47.3475862	best: 47.3475862 (26)	total: 157ms	remaining: 423ms
# 27:	learn: 30.7736743	test: 46.5226159	best: 46.5226159 (27)	total: 160ms	remaining: 410ms
# 28:	learn: 30.2093174	test: 45.6902710	best: 45.6902710 (28)	total: 162ms	remaining: 398ms
# 29:	learn: 29.7340417	test: 44.8331968	best: 44.8331968 (29)	total: 165ms	remaining: 385ms
# 30:	learn: 29.1640121	test: 43.9910438	best: 43.9910438 (30)	total: 167ms	remaining: 371ms
# 31:	learn: 28.6978924	test: 43.1869761	best: 43.1869761 (31)	total: 169ms	remaining: 359ms
# 32:	learn: 28.2121512	test: 42.4281626	best: 42.4281626 (32)	total: 171ms	remaining: 348ms
# 33:	learn: 27.7987184	test: 41.7268664	best: 41.7268664 (33)	total: 173ms	remaining: 337ms
# 34:	learn: 27.4475943	test: 41.0313967	best: 41.0313967 (34)	total: 176ms	remaining: 326ms
# 35:	learn: 27.1179665	test: 40.4607833	best: 40.4607833 (35)	total: 178ms	remaining: 317ms
# 36:	learn: 26.7985496	test: 39.9215386	best: 39.9215386 (36)	total: 181ms	remaining: 308ms
# 37:	learn: 26.4844507	test: 39.4454394	best: 39.4454394 (37)	total: 183ms	remaining: 299ms
# 38:	learn: 26.1276593	test: 38.8501158	best: 38.8501158 (38)	total: 185ms	remaining: 290ms
# 39:	learn: 25.7636987	test: 38.2845287	best: 38.2845287 (39)	total: 187ms	remaining: 281ms
# 40:	learn: 25.4442171	test: 37.7134876	best: 37.7134876 (40)	total: 189ms	remaining: 272ms
# 41:	learn: 25.1293337	test: 36.9883990	best: 36.9883990 (41)	total: 191ms	remaining: 264ms
# 42:	learn: 24.8342339	test: 36.5234758	best: 36.5234758 (42)	total: 193ms	remaining: 256ms
# 43:	learn: 24.5802578	test: 36.1354451	best: 36.1354451 (43)	total: 196ms	remaining: 249ms
# 44:	learn: 24.3396129	test: 35.7137598	best: 35.7137598 (44)	total: 199ms	remaining: 243ms
# 45:	learn: 24.1883603	test: 35.3455771	best: 35.3455771 (45)	total: 201ms	remaining: 236ms
# 46:	learn: 24.0344216	test: 35.0746209	best: 35.0746209 (46)	total: 204ms	remaining: 230ms
# 47:	learn: 23.8566690	test: 34.7713249	best: 34.7713249 (47)	total: 208ms	remaining: 225ms
# 48:	learn: 23.7214317	test: 34.4963193	best: 34.4963193 (48)	total: 211ms	remaining: 219ms
# 49:	learn: 23.5212362	test: 34.1367815	best: 34.1367815 (49)	total: 214ms	remaining: 214ms
# 50:	learn: 23.3671700	test: 33.8457215	best: 33.8457215 (50)	total: 216ms	remaining: 208ms
# 51:	learn: 23.1973369	test: 33.5211293	best: 33.5211293 (51)	total: 219ms	remaining: 202ms
# 52:	learn: 23.0729023	test: 33.3481307	best: 33.3481307 (52)	total: 223ms	remaining: 198ms
# 53:	learn: 22.9778251	test: 33.1700041	best: 33.1700041 (53)	total: 227ms	remaining: 193ms
# 54:	learn: 22.8753356	test: 32.9803328	best: 32.9803328 (54)	total: 230ms	remaining: 188ms
# 55:	learn: 22.7749319	test: 32.7640943	best: 32.7640943 (55)	total: 233ms	remaining: 183ms
# 56:	learn: 22.6325459	test: 32.5013489	best: 32.5013489 (56)	total: 235ms	remaining: 178ms
# 57:	learn: 22.5649185	test: 32.3529538	best: 32.3529538 (57)	total: 237ms	remaining: 172ms
# 58:	learn: 22.4815700	test: 32.2455388	best: 32.2455388 (58)	total: 239ms	remaining: 166ms
# 59:	learn: 22.4113059	test: 32.1327367	best: 32.1327367 (59)	total: 241ms	remaining: 161ms
# 60:	learn: 22.3139495	test: 32.0105683	best: 32.0105683 (60)	total: 244ms	remaining: 156ms
# 61:	learn: 22.2275754	test: 31.8511252	best: 31.8511252 (61)	total: 246ms	remaining: 151ms
# 62:	learn: 22.1200313	test: 31.6871256	best: 31.6871256 (62)	total: 250ms	remaining: 147ms
# 63:	learn: 22.0128762	test: 31.5739920	best: 31.5739920 (63)	total: 253ms	remaining: 143ms
# 64:	learn: 21.9554646	test: 31.4599989	best: 31.4599989 (64)	total: 256ms	remaining: 138ms
# 65:	learn: 21.8985339	test: 31.3514527	best: 31.3514527 (65)	total: 259ms	remaining: 134ms
# 66:	learn: 21.8420971	test: 31.2371984	best: 31.2371984 (66)	total: 262ms	remaining: 129ms
# 67:	learn: 21.7416692	test: 31.1244792	best: 31.1244792 (67)	total: 264ms	remaining: 124ms
# 68:	learn: 21.6567152	test: 31.0196425	best: 31.0196425 (68)	total: 268ms	remaining: 120ms
# 69:	learn: 21.5772233	test: 30.8993869	best: 30.8993869 (69)	total: 270ms	remaining: 116ms
# 70:	learn: 21.4933989	test: 30.7241521	best: 30.7241521 (70)	total: 274ms	remaining: 112ms
# 71:	learn: 21.4158496	test: 30.5899538	best: 30.5899538 (71)	total: 279ms	remaining: 108ms
# 72:	learn: 21.3441629	test: 30.4596082	best: 30.4596082 (72)	total: 281ms	remaining: 104ms
# 73:	learn: 21.2932105	test: 30.3704604	best: 30.3704604 (73)	total: 283ms	remaining: 99.5ms
# 74:	learn: 21.2575416	test: 30.2898358	best: 30.2898358 (74)	total: 286ms	remaining: 95.2ms
# 75:	learn: 21.1771995	test: 30.1913251	best: 30.1913251 (75)	total: 289ms	remaining: 91.3ms
# 76:	learn: 21.1085631	test: 30.0298336	best: 30.0298336 (76)	total: 292ms	remaining: 87.3ms
# 77:	learn: 21.0689862	test: 29.9692440	best: 29.9692440 (77)	total: 295ms	remaining: 83.2ms
# 78:	learn: 21.0157685	test: 29.9203730	best: 29.9203730 (78)	total: 297ms	remaining: 79ms
# 79:	learn: 20.9726778	test: 29.8576345	best: 29.8576345 (79)	total: 299ms	remaining: 74.8ms
# 80:	learn: 20.8897596	test: 29.7700358	best: 29.7700358 (80)	total: 302ms	remaining: 70.9ms
# 81:	learn: 20.8019678	test: 29.6724458	best: 29.6724458 (81)	total: 304ms	remaining: 66.8ms
# 82:	learn: 20.7666471	test: 29.6309974	best: 29.6309974 (82)	total: 307ms	remaining: 63ms
# 83:	learn: 20.7044765	test: 29.5626914	best: 29.5626914 (83)	total: 310ms	remaining: 59ms
# 84:	learn: 20.6320228	test: 29.4518318	best: 29.4518318 (84)	total: 312ms	remaining: 55ms
# 85:	learn: 20.5881829	test: 29.3974040	best: 29.3974040 (85)	total: 313ms	remaining: 51ms
# 86:	learn: 20.5392932	test: 29.3598049	best: 29.3598049 (86)	total: 314ms	remaining: 46.9ms
# 87:	learn: 20.4909382	test: 29.2701040	best: 29.2701040 (87)	total: 315ms	remaining: 43ms
# 88:	learn: 20.4647946	test: 29.2439296	best: 29.2439296 (88)	total: 317ms	remaining: 39.2ms
# 89:	learn: 20.4204151	test: 29.1542995	best: 29.1542995 (89)	total: 318ms	remaining: 35.4ms
# 90:	learn: 20.3730267	test: 29.0931120	best: 29.0931120 (90)	total: 320ms	remaining: 31.6ms
# 91:	learn: 20.3342977	test: 29.0531771	best: 29.0531771 (91)	total: 321ms	remaining: 27.9ms
# 92:	learn: 20.2645012	test: 28.9795586	best: 28.9795586 (92)	total: 322ms	remaining: 24.2ms
# 93:	learn: 20.2440232	test: 28.9223033	best: 28.9223033 (93)	total: 323ms	remaining: 20.6ms
# 94:	learn: 20.2057787	test: 28.8676326	best: 28.8676326 (94)	total: 325ms	remaining: 17.1ms
# 95:	learn: 20.1761832	test: 28.8262406	best: 28.8262406 (95)	total: 326ms	remaining: 13.6ms
# 96:	learn: 20.1368131	test: 28.7358105	best: 28.7358105 (96)	total: 327ms	remaining: 10.1ms
# 97:	learn: 20.0588704	test: 28.6758092	best: 28.6758092 (97)	total: 328ms	remaining: 6.7ms
# 98:	learn: 20.0386928	test: 28.6511808	best: 28.6511808 (98)	total: 330ms	remaining: 3.33ms
# 99:	learn: 19.9895852	test: 28.5878851	best: 28.5878851 (99)	total: 331ms	remaining: 0us
#
# bestTest = 28.58788512
# bestIteration = 99
#
# 0:	loss: 28.5878851	best: 28.5878851 (0)	total: 352ms	remaining: 18.6s
# 0:	learn: 69.9471211	test: 95.3178033	best: 95.3178033 (0)	total: 1.24ms	remaining: 122ms
# 1:	learn: 64.2668527	test: 88.5252911	best: 88.5252911 (1)	total: 2.47ms	remaining: 121ms
# 2:	learn: 59.2531262	test: 83.2891116	best: 83.2891116 (2)	total: 3.77ms	remaining: 122ms
# 3:	learn: 54.9092711	test: 77.8075627	best: 77.8075627 (3)	total: 5.25ms	remaining: 126ms
# 4:	learn: 50.8696366	test: 72.9207902	best: 72.9207902 (4)	total: 6.49ms	remaining: 123ms
# 5:	learn: 47.2111927	test: 68.5537112	best: 68.5537112 (5)	total: 7.59ms	remaining: 119ms
# 6:	learn: 44.0541002	test: 64.7054893	best: 64.7054893 (6)	total: 8.69ms	remaining: 115ms
# 7:	learn: 41.0535957	test: 60.6881072	best: 60.6881072 (7)	total: 10.4ms	remaining: 120ms
# 8:	learn: 38.6148448	test: 57.5852298	best: 57.5852298 (8)	total:
# <b>limit_output extension: Maximum message size of 10000 exceeded with 10759 characters</b>

# %%
grid_search_result['params']
# Out:
# {'depth': 6, 'l2_leaf_reg': 3, 'iterations': 200, 'learning_rate': 0.1}

# %%
catboost_best = CatBoostRegressor(depth=6, l2_leaf_reg=3, iterations=200, learning_rate=0.1)

# %%
catboost_best.fit(train_X, train_y)
# Out:
# 0:	learn: 34.0832901	total: 1.12ms	remaining: 222ms
# 1:	learn: 32.5959544	total: 2.41ms	remaining: 238ms
# 2:	learn: 31.3529366	total: 4.41ms	remaining: 289ms
# 3:	learn: 30.4757209	total: 5.91ms	remaining: 290ms
# 4:	learn: 29.5272550	total: 7.21ms	remaining: 281ms
# 5:	learn: 28.5724114	total: 8.59ms	remaining: 278ms
# 6:	learn: 27.8865087	total: 9.77ms	remaining: 269ms
# 7:	learn: 27.2200184	total: 11ms	remaining: 264ms
# 8:	learn: 26.6340578	total: 12.2ms	remaining: 260ms
# 9:	learn: 26.2000567	total: 13.4ms	remaining: 255ms
# 10:	learn: 25.8164796	total: 14.7ms	remaining: 253ms
# 11:	learn: 25.4333100	total: 15.7ms	remaining: 246ms
# 12:	learn: 25.1019714	total: 16.8ms	remaining: 241ms
# 13:	learn: 24.8130296	total: 18.1ms	remaining: 240ms
# 14:	learn: 24.5090706	total: 19.4ms	remaining: 240ms
# 15:	learn: 24.2802326	total: 20.8ms	remaining: 240ms
# 16:	learn: 24.0664830	total: 22.2ms	remaining: 239ms
# 17:	learn: 23.8255257	total: 23.6ms	remaining: 238ms
# 18:	learn: 23.6775256	total: 24.9ms	remaining: 237ms
# 19:	learn: 23.4881598	total: 26.5ms	remaining: 238ms
# 20:	learn: 23.3181898	total: 28.6ms	remaining: 244ms
# 21:	learn: 23.2013080	total: 30.3ms	remaining: 245ms
# 22:	learn: 23.0761367	total: 32.1ms	remaining: 247ms
# 23:	learn: 22.9789301	total: 33.6ms	remaining: 246ms
# 24:	learn: 22.8882155	total: 35.2ms	remaining: 246ms
# 25:	learn: 22.7301611	total: 36.6ms	remaining: 245ms
# 26:	learn: 22.6318691	total: 38.3ms	remaining: 246ms
# 27:	learn: 22.5672854	total: 39.7ms	remaining: 244ms
# 28:	learn: 22.5014673	total: 41.2ms	remaining: 243ms
# 29:	learn: 22.4110255	total: 42.5ms	remaining: 241ms
# 30:	learn: 22.3029402	total: 43.5ms	remaining: 237ms
# 31:	learn: 22.2131440	total: 44.6ms	remaining: 234ms
# 32:	learn: 22.1388165	total: 45.7ms	remaining: 232ms
# 33:	learn: 22.0695382	total: 47.4ms	remaining: 232ms
# 34:	learn: 21.9794696	total: 48.8ms	remaining: 230ms
# 35:	learn: 21.8915940	total: 50ms	remaining: 228ms
# 36:	learn: 21.8269659	total: 51.1ms	remaining: 225ms
# 37:	learn: 21.7702062	total: 52.6ms	remaining: 224ms
# 38:	learn: 21.6780488	total: 54ms	remaining: 223ms
# 39:	learn: 21.6115416	total: 55.2ms	remaining: 221ms
# 40:	learn: 21.5727705	total: 56.3ms	remaining: 219ms
# 41:	learn: 21.4394395	total: 57.6ms	remaining: 217ms
# 42:	learn: 21.2998837	total: 58.8ms	remaining: 215ms
# 43:	learn: 21.1527658	total: 60.2ms	remaining: 213ms
# 44:	learn: 21.0399622	total: 61.7ms	remaining: 213ms
# 45:	learn: 20.9695310	total: 63.2ms	remaining: 212ms
# 46:	learn: 20.8705817	total: 64.5ms	remaining: 210ms
# 47:	learn: 20.8249790	total: 66ms	remaining: 209ms
# 48:	learn: 20.7620067	total: 67.2ms	remaining: 207ms
# 49:	learn: 20.7168597	total: 68.3ms	remaining: 205ms
# 50:	learn: 20.6584154	total: 69.4ms	remaining: 203ms
# 51:	learn: 20.5525567	total: 70.5ms	remaining: 201ms
# 52:	learn: 20.4834987	total: 71.6ms	remaining: 199ms
# 53:	learn: 20.4447383	total: 72.6ms	remaining: 196ms
# 54:	learn: 20.4125155	total: 73.5ms	remaining: 194ms
# 55:	learn: 20.3907993	total: 74.5ms	remaining: 191ms
# 56:	learn: 20.3588023	total: 75.6ms	remaining: 190ms
# 57:	learn: 20.3177771	total: 77.4ms	remaining: 189ms
# 58:	learn: 20.2285959	total: 78.8ms	remaining: 188ms
# 59:	learn: 20.1821711	total: 80.1ms	remaining: 187ms
# 60:	learn: 20.1292128	total: 81.7ms	remaining: 186ms
# 61:	learn: 20.0943890	total: 83ms	remaining: 185ms
# 62:	learn: 20.0594405	total: 84ms	remaining: 183ms
# 63:	learn: 20.0207781	total: 85.3ms	remaining: 181ms
# 64:	learn: 19.9516571	total: 86.3ms	remaining: 179ms
# 65:	learn: 19.9339900	total: 87.3ms	remaining: 177ms
# 66:	learn: 19.9118224	total: 88.3ms	remaining: 175ms
# 67:	learn: 19.8363661	total: 89.3ms	remaining: 173ms
# 68:	learn: 19.7830246	total: 90.5ms	remaining: 172ms
# 69:	learn: 19.7590120	total: 91.6ms	remaining: 170ms
# 70:	learn: 19.7261750	total: 92.6ms	remaining: 168ms
# 71:	learn: 19.6838765	total: 93.7ms	remaining: 167ms
# 72:	learn: 19.6382768	total: 94.7ms	remaining: 165ms
# 73:	learn: 19.6061597	total: 95.8ms	remaining: 163ms
# 74:	learn: 19.5480792	total: 96.8ms	remaining: 161ms
# 75:	learn: 19.4993242	total: 97.8ms	remaining: 160ms
# 76:	learn: 19.4660366	total: 98.8ms	remaining: 158ms
# 77:	learn: 19.4012713	total: 99.8ms	remaining: 156ms
# 78:	learn: 19.3783284	total: 101ms	remaining: 154ms
# 79:	learn: 19.3533550	total: 102ms	remaining: 153ms
# 80:	learn: 19.3398415	total: 103ms	remaining: 151ms
# 81:	learn: 19.2781665	total: 104ms	remaining: 149ms
# 82:	learn: 19.2374535	total: 105ms	remaining: 148ms
# 83:	learn: 19.1905867	total: 106ms	remaining: 147ms
# 84:	learn: 19.1520505	total: 108ms	remaining: 146ms
# 85:	learn: 19.1379719	total: 109ms	remaining: 144ms
# 86:	learn: 19.0916857	total: 110ms	remaining: 142ms
# 87:	learn: 19.0480224	total: 111ms	remaining: 141ms
# 88:	learn: 19.0078728	total: 112ms	remaining: 139ms
# 89:	learn: 18.9530765	total: 113ms	remaining: 138ms
# 90:	learn: 18.9051980	total: 114ms	remaining: 136ms
# 91:	learn: 18.8767628	total: 116ms	remaining: 136ms
# 92:	learn: 18.8371728	total: 117ms	remaining: 135ms
# 93:	learn: 18.8280246	total: 118ms	remaining: 133ms
# 94:	learn: 18.8012599	total: 119ms	remaining: 132ms
# 95:	learn: 18.7844336	total: 120ms	remaining: 130ms
# 96:	learn: 18.7502381	total: 121ms	remaining: 129ms
# 97:	learn: 18.7307252	total: 122ms	remaining: 127ms
# 98:	learn: 18.6788720	total: 123ms	remaining: 126ms
# 99:	learn: 18.6387437	total: 125ms	remaining: 125ms
# 100:	learn: 18.6287325	total: 126ms	remaining: 123ms
# 101:	learn: 18.6068386	total: 127ms	remaining: 122ms
# 102:	learn: 18.5679908	total: 128ms	remaining: 120ms
# 103:	learn: 18.5314924	total: 129ms	remaining: 119ms
# 104:	learn: 18.4965729	total: 130ms	remaining: 117ms
# 105:	learn: 18.4810910	total: 131ms	remaining: 116ms
# 106:	learn: 18.4475579	total: 131ms	remaining: 114ms
# 107:	learn: 18.4438364	total: 132ms	remaining: 113ms
# 108:	learn: 18.4145361	total: 133ms	remaining: 111ms
# 109:	learn: 18.3939811	total: 134ms	remaining: 110ms
# 110:	learn: 18.3689949	total: 136ms	remaining: 109ms
# 111:	learn: 18.3638926	total: 137ms	remaining: 108ms
# 112:	learn: 18.3346522	total: 138ms	remaining: 106ms
# 113:	learn: 18.3270913	total: 139ms	remaining: 105ms
# 114:	learn: 18.2779372	total: 140ms	remaining: 104ms
# 115:	learn: 18.2530353	total: 141ms	remaining: 102ms
# 116:	learn: 18.2503885	total: 142ms	remaining: 101ms
# 117:	learn: 18.2156196	total: 143ms	remaining: 99.5ms
# 118:	learn: 18.1918634	total: 144ms	remaining: 98.1ms
# 119:	learn: 18.1573908	total: 145ms	remaining: 96.8ms
# 120:	learn: 18.1550368	total: 146ms	remaining: 95.4ms
# 121:	learn: 18.1296798	total: 147ms	remaining: 94.2ms
# 122:	learn: 18.1027240	total: 148ms	remaining: 92.9ms
# 123:	learn: 18.0741518	total: 150ms	remaining: 92.2ms
# 124:	learn: 18.0237140	total: 151ms	remaining: 90.8ms
# 125:	learn: 18.0205843	total: 152ms	remaining: 89.5ms
# 126:	learn: 17.9943594	total: 154ms	remaining: 88.2ms
# 127:	learn: 17.9490903	total: 155ms	remaining: 86.9ms
# 128:	learn: 17.9228727	total: 156ms	remaining: 85.6ms
# 129:	learn: 17.9067589	total: 156ms	remaining: 84.2ms
# 130:	learn: 17.8876191	total: 157ms	remaining: 82.9ms
# 131:	learn: 17.8669031	total: 158ms	remaining: 81.6ms
# 132:	learn: 17.8394568	total: 159ms	remaining: 80.3ms
# 133:	learn: 17.8085962	total: 160ms	remaining: 79ms
# 134:	learn: 17.7837402	total: 162ms	remaining: 77.8ms
# 135:	learn: 17.7805760	total: 163ms	remaining: 76.5ms
# 136:	learn: 17.7415933	total: 164ms	remaining: 75.4ms
# 137:	learn: 17.7233682	total: 165ms	remaining: 74.3ms
# 138:	learn: 17.7073608	total: 167ms	remaining: 73.2ms
# 139:	learn: 17.7044529	total: 168ms	remaining: 72ms
# 140:	learn: 17.6789457	total: 169ms	remaining: 70.9ms
# 141:	learn: 17.6764972	total: 171ms	remaining: 69.8ms
# 142:	learn: 17.6518417	total: 172ms	remaining: 68.5ms
# 143:	learn: 17.6306934	total: 173ms	remaining: 67.2ms
# 144:	learn: 17.5731676	total: 174ms	remaining: 65.9ms
# 145:	learn: 17.5497824	total: 175ms	remaining: 64.7ms
# 146:	learn: 17.5178135	total: 176ms	remaining: 63.5ms
# 147:	learn: 17.4904086	total: 177ms	remaining: 62.3ms
# 148:	learn: 17.4739649	total: 179ms	remaining: 61.2ms
# 149:	learn: 17.4484792	total: 180ms	remaining: 60ms
# 150:	learn: 17.4330021	total: 181ms	remaining: 58.8ms
# 151:	learn: 17.4187888	total: 183ms	remaining: 57.8ms
# 152:	learn: 17.3974839	total: 185ms	remaining: 56.7ms
# 153:	learn: 17.3702194	total: 186ms	remaining: 55.5ms
# 154:	learn: 17.3601783	total: 187ms	remaining: 54.4ms
# 155:	learn: 17.3353919	total: 189ms	remaining: 53.2ms
# 156:	learn: 17.3340795	total: 190ms	remaining: 52ms
# 157:	learn: 17.3101789	total: 191ms	remaining: 50.9ms
# 158:	learn: 17.2921277	total: 193ms	remaining: 49.7ms
# 159:	learn: 17.2847641	total: 194ms	remaining: 48.4ms
# 160:	learn: 17.2518710	total: 195ms	remaining: 47.3ms
# 161:	learn: 17.2175896	total: 197ms	remaining: 46.1ms
# 162:	learn: 17.2061244	total: 198ms	remaining: 44.9ms
# 163:	learn: 17.2007614	total: 199ms	remaining: 43.6ms
# 164:	learn: 17.1991070	total: 200ms	remaining: 42.5ms
# 165:	learn: 17.1718133	total: 202ms	remaining: 41.3ms
# 166:	learn: 17.1332202	total: 203ms	remaining: 40.1ms
# 167:	learn: 17.1037924	total: 204ms	remaining: 38.9ms
# 168:	learn: 17.0707576	total: 205ms	remaining: 37.6ms
# 169:	learn: 17.0333093	total: 206ms	remaining: 36.4ms
# 170:	learn: 17.0046877	total: 208ms	remaining: 35.2ms
# 171:	learn: 16.9883714	total: 209ms	remaining: 34ms
# 172:	learn: 16.9867437	total: 211ms	remaining: 32.9ms
# 173:	learn: 16.9811377	total: 212ms	remaining: 31.7ms
# 174:	learn: 16.9588746	total: 214ms	remaining: 30.6ms
# 175:	learn: 16.9401672	total: 215ms	remaining: 29.4ms
# 176:	learn: 16.9018793	total: 217ms	remaining: 28.1ms
# 177:	learn: 16.8830280	total: 218ms	remaining: 26.9ms
# 178:	learn: 16.8811819	total: 219ms	remaining: 25.7ms
# 179:	learn: 16.8713874	total: 221ms	remaining: 24.5ms
# 180:	learn: 16.8538424	total: 222ms	remaining: 23.3ms
# 181:	learn: 16.8363983	total: 223ms	remaining: 22ms
# 182:	learn: 16.8101527	total: 224ms	remaining: 20.8ms
# 183:	learn: 16.8038824	total: 225ms	remaining: 19.6ms
# 184:	learn: 16.7782477	total: 227ms	remaining: 18.4ms
# 185:	learn: 16.7680495	total: 229ms	remaining: 17.2ms
# 186:	learn: 16.7463293	total: 230ms	remaining: 16ms
# 187:	learn: 16.7283272	total: 232ms	remaining: 14.8ms
# 188:	learn: 16.7089928
# <b>limit_output extension: Maximum message size of 10000 exceeded with 10622 characters</b>

# %%
# %%time
catboost_predictions_test = catboost_best.predict(test_X)
# Out:
# CPU times: user 3.81 ms, sys: 1.61 ms, total: 5.42 ms
# Wall time: 2.93 ms

# %%
cat_rmse_test = round(mean_squared_error(test_y, catboost_predictions_test)**0.5, 2)
print('RMSE on test:', cat_rmse_test)
# Out:
# RMSE on test: 45.68

# %% [markdown]
# ## Dummy models

# %% [markdown]
# ### Constant Model

# %%
pred_mean = np.ones(test_y.shape) * train_y.mean()
constant_rmse = round(mean_squared_error(test_y, pred_mean)**0.5)
print('RMSE on test:', constant_rmse)
# Out:
# RMSE on test: 74

# %% [markdown]
# ### Naive Model

# %% [markdown]
# This model's prediction is a preceding value.

# %%
pred_previous = test_y.shift()
pred_previous.iloc[0] = train_y.iloc[-1]
naive_rmse = round(mean_squared_error(test_y, pred_previous)**0.5)
print('RMSE on test:', naive_rmse)
# Out:
# RMSE on test: 53

# %% [markdown]
# # Models Comparison

# %%
d = {'RSME on test': [lm_rmse_test, rfr_rmse_test, knn_rmse_test, lgbm_rmse_test, 
                      cat_rmse_test, constant_rmse, naive_rmse],
    'Prediction time, ms': [2.41, 11.5, 14.7, 4.28, 1.98, '--', '--']}

final = pd.DataFrame(data=d, index=['Linear Regression', 'Random Forest Regression', 'KNeighbors Regressor',
                                    'LightGBMRegressor', 'CatBoost', 'Constant Model', 'Naive Model'])
display(final)
# Out:
#                           RSME on test Prediction time, ms
# Linear Regression                47.52                2.41
# Random Forest Regression         45.76                11.5
# KNeighbors Regressor             57.57                14.7
# LightGBMRegressor                45.39                4.28
# CatBoost                         45.68                1.98
# Constant Model                   74.00                  --
# Naive Model                      53.00                  --

# %% [markdown]
# # Conclusion

# %% [markdown]
#  1. We loaded the data and set the time stamp column as indices. We sorted the data set in chronological order.<br>
#  2. We checked trend and seasonality in the data. There is an upward trend in number in rides from March to August. Also, the data has weekly seasonality: the pattern in number of rides repeats every week with two peaks: Mondays and Fridays.
#  3. We generated additional features to train models: month, day, day of the week, hour and five lag columns.<br>
#  4. We tested five models. Our target RMSE metric was set to be no more than 48. Four models out of five demonstrate acceptable RMSE values. The only model whose RMSE is higher is the KNeighbors Resgressot, its prediction time is the highest too. The Random Forest Regressor gives the best RMSE, but its run time is quite high. The best model for our task is the Catboost with RMSE of 45.68 and runtime 1.98 ms.
